# %% [markdown]
# <a href="https://colab.research.google.com/github/artem-tkachuk/cs182-project-pointnet/blob/main/train_pointnet_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !cd drive/MyDrive/pointnet.pytorch && pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/pointnet.pytorch
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for pointnet
# ...

# %%
# !cd drive/MyDrive/pointnet.pytorch/scripts && bash build.sh
# Out:
# /content/drive/MyDrive/pointnet.pytorch/scripts

# %%
# !cd drive/MyDrive/pointnet.pytorch/scripts && bash download.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/46ae88cad17edca7ae7c0d0e12bd33da.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/1ea7a36e4f353416fe1f6e05091d5d9.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/e94ad5f8e53a255a8fc2d09ac4aa4e78.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/8b61ba80d9e487deca8607f540cc62ba.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/3cbc83ba49edeccebc0909d98a1ff2b4.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/c5d0dd7a7b44b079a76ffc04f04676cb.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/75db11c354c6342aad01ec966c80ac91.png
#   inflating: shapenetcore_partanno_segmentation_benchmark_v0/02691156/seg_img/37b413fb76f97e0a29ad19c61d540866.png
# ...

# %%
# !python /content/drive/MyDrive/pointnet.pytorch/utils/train_classification.py --dataset /content/drive/MyDrive/pointnet.pytorch/shapenetcore_partanno_segmentation_benchmark_v0/ --nepoch=2 --dataset_type shapenet --feature_transform
# Out:
# Namespace(batchSize=32, num_points=2500, workers=4, nepoch=2, outf='cls', model='', dataset='/content/drive/MyDrive/pointnet.pytorch/shapenetcore_partanno_segmentation_benchmark_v0/', dataset_type='shapenet', feature_transform=True)
# Random Seed:  5421
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# ...

# %%
# !python /content/drive/MyDrive/pointnet.pytorch/utils/show_cls.py --model=/content/drive/MyDrive/pointnet.pytorch/pointnet/model.py
# Out:
# Namespace(model='/content/drive/MyDrive/pointnet.pytorch/pointnet/model.py', num_points=2500)
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/pointnet.pytorch/utils/show_cls.py", line 35, in <module>
#     classifier.load_state_dict(torch.load(opt.model))
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 795, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 1002, in _legacy_load
# ...
