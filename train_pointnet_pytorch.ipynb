# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls

# %%
# TODO don't forget to change runtime type to GPT

# %%
# TODO install our repo
# !git clone https://github.com/artem-tkachuk/cs182-project-pointnet.git drive/MyDrive/cs182-pointnet-homework
# Out:
# Cloning into 'drive/MyDrive/cs182-pointnet-homework'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 42 (delta 1), reused 36 (delta 1), pack-reused 0
# Unpacking objects: 100% (42/42), 303.70 KiB | 7.99 MiB/s, done.

# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/xlsior/Library/Mobile%20Documents/com~apple~CloudDocs/Berkeley/Semesters/Spring%202023/CS182/Project/cs182-project-pointnet
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: pointnet
#     Found existing installation: pointnet 0.0.1
#     Uninstalling pointnet-0.0.1:
#       Successfully uninstalled pointnet-0.0.1
#   Running setup.py develop for pointnet
# ...

# %%
# !cd drive/MyDrive/cs182-pointnet-homework && pip install -e .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/drive/MyDrive/cs182-pointnet-homework
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for pointnet
# ...

# %%
# !bash scripts/download.sh
# Out:
# scripts/download.sh: line 1: realpath: command not found
# usage: dirname string [...]
# --2023-04-19 18:47:24--  https://shapenet.cs.stanford.edu/ericyi/shapenetcore_partanno_segmentation_benchmark_v0.zip
# Resolving shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)... 171.67.77.19
# Connecting to shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)|171.67.77.19|:443... connected.
# WARNING: cannot verify shapenet.cs.stanford.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Issued certificate has expired.
# HTTP request sent, awaiting response... 200 OK
# Length: 666265910 (635M) [application/zip]
# shapenetcore_partanno_segmentation_benchmark_v0.zip: Read-only file system
#
# Cannot write to ‘shapenetcore_partanno_segmentation_benchmark_v0.zip’ (Success).
# ...

# %%
# !cd drive/MyDrive/cs182-pointnet-homework/scripts && bash build.sh
# Out:
# /content/drive/MyDrive/cs182-pointnet-homework/scripts

# %%
showpoints(np.random.randn(2500, 3))

# %%
from utils.show3d_balls import showpoints

showpoints(np.random.randn(2500, 3))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from utils.show3d_balls import showpoints
#       3 showpoints(np.random.randn(2500, 3))
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Semesters/Spring 2023/CS182/Project/cs182-project-pointnet/utils/show3d_balls.py:25
#      22 cv2.moveWindow('show3d', 0, 0)
#      23 cv2.setMouseCallback('show3d', onmouse)
# ---> 25 dll = np.ctypeslib.load_library('render_balls_so', '.')
#      28 def showpoints(xyz, c_gt=None, c_pred=None, waittime=0,
#      29                showrot=False, magnifyBlue=0, freezerot=False, background=(0, 0, 0),
#      30                normalizecolor=True, ballradius=10):
#      31     global showsz, mousex, mousey, zoom, changed
#
# ...

# %% [markdown]
# # Classification training

# %%
# !python /content/drive/MyDrive/cs182-pointnet-homework/utils/train_classification.py --dataset /content/drive/MyDrive/cs182-pointnet-homework/shapenetcore_partanno_segmentation_benchmark_v0/ --nepoch=2 --dataset_type shapenet --feature_transform
# Out:
# Namespace(batchSize=32, num_points=2500, workers=4, nepoch=2, outf='cls', model='', dataset='/content/drive/MyDrive/cs182-pointnet-homework/shapenetcore_partanno_segmentation_benchmark_v0/', dataset_type='shapenet', feature_transform=True)
# Random Seed:  3419
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# ...

# %% [markdown]
# # Classification visualization

# %%
# !python /content/drive/MyDrive/cs182-pointnet-homework/utils/show_cls.py --model=/content/drive/MyDrive/cs182-pointnet-homework/pointnet/model.py
# Out:
# Namespace(model='/content/drive/MyDrive/cs182-pointnet-homework/pointnet/model.py', num_points=2500)
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/cs182-pointnet-homework/utils/show_cls.py", line 35, in <module>
#     classifier.load_state_dict(torch.load(opt.model))
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 815, in load
#     return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#   File "/usr/local/lib/python3.9/dist-packages/torch/serialization.py", line 1033, in _legacy_load
# ...

# %% [markdown]
# # Segmentation training

# %%
# !python /content/drive/MyDrive/cs182-pointnet-homework/utils/train_segmentation.py --dataset /content/drive/MyDrive/cs182-pointnet-homework/shapenetcore_partanno_segmentation_benchmark_v0/ --nepoch=2
# Out:
# Namespace(batchSize=32, workers=4, nepoch=2, outf='seg', model='', dataset='/content/drive/MyDrive/cs182-pointnet-homework/shapenetcore_partanno_segmentation_benchmark_v0/', class_choice='Chair', feature_transform=False)
# Random Seed:  5112
# {'Chair': 0}
# {'Airplane': 4, 'Bag': 2, 'Cap': 2, 'Car': 4, 'Chair': 4, 'Earphone': 3, 'Guitar': 3, 'Knife': 2, 'Lamp': 4, 'Laptop': 2, 'Motorbike': 6, 'Mug': 2, 'Pistol': 3, 'Rocket': 3, 'Skateboard': 3, 'Table': 3} 4
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# {'Chair': 0}
# ...

# %% [markdown]
# # Segmentation visualization

# %%
# !pip install opencv-contrib-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 MB 10.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install ctypes
# Out:
# ERROR: Could not find a version that satisfies the requirement ctypes (from versions: none)
# ERROR: No matching distribution found for ctypes

# %%
# !g++ -std=c++11 ./utils/render_balls_so.cpp -o ./utils/render_balls_so.so -shared -fPIC -O2 -D_GLIBCXX_USE_CXX11_ABI=0

# %%
# !python ./utils/show_seg.py --model=./seg/seg_model_Chair_1.pth --dataset ./shapenetcore_partanno_segmentation_benchmark_v0/ --class_choice 'Chair' --idx 1
# Out:
# Traceback (most recent call last):
#   File "./utils/show_seg.py", line 2, in <module>
#     from show3d_balls import showpoints
#   File "/Users/xlsior/Library/Mobile Documents/com~apple~CloudDocs/Berkeley/Semesters/Spring 2023/CS182/Project/cs182-project-pointnet/utils/show3d_balls.py", line 25, in <module>
#     dll = np.ctypeslib.load_library('utils/render_balls_so', '.')
#   File "/Users/xlsior/opt/anaconda3/envs/cs182-project-pointnet/lib/python3.8/site-packages/numpy/ctypeslib.py", line 163, in load_library
#     raise OSError("no file with expected extension")
# OSError: no file with expected extension
